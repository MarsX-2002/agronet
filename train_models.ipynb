# %% [markdown]
# # Multi-Product YOLOv11 Training Pipeline
# This notebook handles the configuration and training of three separate object detection models: Potato, Carrot, and Lemon.

# %%
import os
import yaml
from ultralytics import YOLO

# Define base directory
BASE_DIR = os.path.abspath(os.getcwd())
print(f"Working in: {BASE_DIR}")
# Out:
# Working in: /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning

# %%
def fix_data_yaml(dataset_dir):
    yaml_path = os.path.join(BASE_DIR, dataset_dir, "data.yaml")
    if not os.path.exists(yaml_path):
        print(f"Skipping {dataset_dir}, data.yaml not found.")
        return

    with open(yaml_path, 'r') as f:
        data = yaml.safe_load(f)

    # Update paths to absolute to prevent YOLO errors
    data['train'] = os.path.join(BASE_DIR, dataset_dir, "train/images")
    data['val'] = os.path.join(BASE_DIR, dataset_dir, "valid/images")
    data['test'] = os.path.join(BASE_DIR, dataset_dir, "test/images")

    with open(yaml_path, 'w') as f:
        yaml.dump(data, f)
    print(f"Fixed paths in {yaml_path}")

# Fix all datasets
datasets = ["dataset_potato", "dataset_carrot", "dataset_lemon"]
for ds in datasets:
    fix_data_yaml(ds)
# Out:
# Fixed paths in /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_potato/data.yaml
# Fixed paths in /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_carrot/data.yaml
# Fixed paths in /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_lemon/data.yaml

# %% [markdown]
# ## 1. Train Potato Model
# Using **YOLOv11s** (Small) due to large dataset size (~12k images).

# %%
model_potato = YOLO('yolo11s.pt')
results_potato = model_potato.train(
    data=os.path.join(BASE_DIR, "dataset_potato/data.yaml"),
    epochs=5, 
    imgsz=640,
    project='runs/detect',
    name='potato_v11',
    augment=True,
    degrees=90,
    fliplr=0.5,
    exist_ok=True
)
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_potato/data.yaml, degrees=90, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=5, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=potato_v11, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/mikey/Desktop/pipeline/runs/detect/runs/detect/potato_v11, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820956  ultralytics.nn.modules.head.Detect           [4, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,429,340 parameters, 9,429,324 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 100.3±51.6 MB/s, size: 26.8 KB)
# train: Scanning /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_potato/train/labels.cache... 12558 images, 5370 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 12558/12558 2.9Git/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 12, len(boxes) = 28902. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 149.5±59.1 MB/s, size: 46.3 KB)
# val: Scanning /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_potato/valid/labels.cache... 1002 images, 426 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1002/1002 60.9Mit/s 0.0s
# Plotting labels to /home/mikey/Desktop/pipeline/runs/detect/runs/detect/potato_v11/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/mikey/Desktop/pipeline/runs/detect/runs/detect/potato_v11
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5      4.34G      1.443      2.282      1.677         69        640: 100% ━━━━━━━━━━━━ 785/785 4.2it/s 3:05<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 3.8it/s 8.4s0.2s
#                    all       1002       2031      0.262      0.487      0.254      0.117
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5      4.29G      1.342      1.929      1.588         28        640: 100% ━━━━━━━━━━━━ 785/785 4.7it/s 2:49<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 5.7it/s 5.6s0.2s
#                    all       1002       2031      0.423      0.502      0.418      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5      4.25G      1.253      1.793      1.524         41        640: 100% ━━━━━━━━━━━━ 785/785 4.7it/s 2:47<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 5.9it/s 5.4s0.2s
#                    all       1002       2031      0.447      0.532       0.49      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5      4.23G      1.156      1.614      1.454         56        640: 100% ━━━━━━━━━━━━ 785/785 4.7it/s 2:46<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 5.7it/s 5.6s0.2s
#                    all       1002       2031      0.327      0.556      0.377      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5       4.1G      1.067      1.459      1.401         39        640: 100% ━━━━━━━━━━━━ 785/785 4.7it/s 2:47<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 5.8it/s 5.6s0.2s
#                    all       1002       2031      0.456      0.583      0.547      0.367
#
# 5 epochs completed in 0.246 hours.
# Optimizer stripped from /home/mikey/Desktop/pipeline/runs/detect/runs/detect/potato_v11/weights/last.pt, 19.2MB
# Optimizer stripped from /home/mikey/Desktop/pipeline/runs/detect/runs/detect/potato_v11/weights/best.pt, 19.2MB
#
# Validating /home/mikey/Desktop/pipeline/runs/detect/runs/detect/potato_v11/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# YOLO11s summary (fused): 101 layers, 9,414,348 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 32/32 1.9it/s 16.8s0.3s
#                    all       1002       2031      0.449       0.63       0.57      0.393
#         Potato_Damaged        200        659      0.272      0.622      0.407      0.281
#          Potato_Fungal        217        427      0.416      0.562      0.567      0.451
#         Potato_Healthy        169        646      0.527      0.459      0.505      0.372
#        Potato_Sprouted         73        299      0.582      0.876        0.8      0.469
# Speed: 0.2ms preprocess, 15.3ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /home/mikey/Desktop/pipeline/runs/detect/runs/detect/potato_v11

# %% [markdown]
# ## 2. Train Carrot Model
# Using **YOLOv11n** (Nano) for efficiency.

# %%
model_carrot = YOLO('yolo11n.pt')
results_carrot = model_carrot.train(
    data=os.path.join(BASE_DIR, "dataset_carrot/data.yaml"),
    epochs=20,
    imgsz=640,
    project='runs/detect',
    name='carrot_v11',
    augment=True,
    degrees=180,
    fliplr=0.5,
    exist_ok=True
)
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_carrot/data.yaml, degrees=180, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=carrot_v11, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/mikey/Desktop/pipeline/runs/detect/runs/detect/carrot_v11, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 232.6±79.7 MB/s, size: 65.5 KB)
# train: Scanning /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_carrot/train/labels.cache... 342 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 342/342 89.7Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 88.3±39.5 MB/s, size: 48.2 KB)
# val: Scanning /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_carrot/valid/labels.cache... 25 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 25/25 2.2Mit/s 0.0s
# Plotting labels to /home/mikey/Desktop/pipeline/runs/detect/runs/detect/carrot_v11/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/mikey/Desktop/pipeline/runs/detect/runs/detect/carrot_v11
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      2.35G      2.231      3.107      2.444         52        640: 100% ━━━━━━━━━━━━ 22/22 1.5it/s 15.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.7s/it 1.7s
#                    all         25        104    0.00644       0.37     0.0225    0.00635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.36G      1.928      2.754      2.201         44        640: 100% ━━━━━━━━━━━━ 22/22 9.0it/s 2.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 9.4it/s 0.1s
#                    all         25        104      0.852     0.0516      0.149     0.0321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      2.36G      1.937      2.443      2.247         55        640: 100% ━━━━━━━━━━━━ 22/22 9.3it/s 2.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 9.1it/s 0.1s
#                    all         25        104      0.704       0.13      0.155     0.0474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      2.37G      1.903      2.337      2.224         47        640: 100% ━━━━━━━━━━━━ 22/22 9.6it/s 2.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 9.3it/s 0.1s
#                    all         25        104      0.673      0.283      0.174      0.065
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.38G      1.851      2.237      2.181         44        640: 100% ━━━━━━━━━━━━ 22/22 9.7it/s 2.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 9.2it/s 0.1s
#                    all         25        104      0.678      0.299      0.244     0.0846
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      2.39G      1.784      2.128      2.107         66        640: 100% ━━━━━━━━━━━━ 22/22 9.7it/s 2.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 9.9it/s 0.1s
#                    all         25        104      0.143      0.234      0.134     0.0481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      2.39G      1.764      2.091      2.091         37        640: 100% ━━━━━━━━━━━━ 22/22 9.8it/s 2.3s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.5it/s 0.1s
#                    all         25        104      0.705      0.204      0.184      0.051
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      2.39G      1.778      2.066      2.069         60        640: 100% ━━━━━━━━━━━━ 22/22 9.7it/s 2.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 11.1it/s 0.1s
#                    all         25        104      0.698      0.248      0.171     0.0532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20       2.4G       1.76      2.045       2.07         64        640: 100% ━━━━━━━━━━━━ 22/22 9.7it/s 2.3s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.6it/s 0.1s
#                    all         25        104      0.778        0.3      0.272     0.0958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20       2.4G      1.727      2.045       2.06         42        640: 100% ━━━━━━━━━━━━ 22/22 9.6it/s 2.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.8it/s 0.1s
#                    all         25        104      0.806      0.364      0.325      0.115
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      2.41G       1.67      2.214      2.125         22        640: 100% ━━━━━━━━━━━━ 22/22 7.8it/s 2.8s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.8it/s 0.1s
#                    all         25        104      0.583      0.103     0.0579     0.0137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      2.42G      1.609      2.021      2.065         18        640: 100% ━━━━━━━━━━━━ 22/22 9.9it/s 2.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 11.2it/s 0.1s
#                    all         25        104      0.686      0.196      0.169     0.0456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      2.42G      1.557      1.945      2.022         16        640: 100% ━━━━━━━━━━━━ 22/22 10.0it/s 2.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.3it/s 0.1s
#                    all         25        104      0.791      0.359      0.349      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      2.42G      1.575      1.937      2.021         29        640: 100% ━━━━━━━━━━━━ 22/22 10.0it/s 2.2s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.4it/s 0.1s
#                    all         25        104      0.336      0.315      0.341      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      2.42G      1.538      1.854      2.011         20        640: 100% ━━━━━━━━━━━━ 22/22 10.0it/s 2.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 11.0it/s 0.1s
#                    all         25        104      0.804      0.387      0.408      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      2.42G      1.541      1.798      1.987         26        640: 100% ━━━━━━━━━━━━ 22/22 9.9it/s 2.2s<0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 11.1it/s 0.1s
#                    all         25        104      0.762      0.364      0.289      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      2.42G      1.506      1.783      1.943         30        640: 100% ━━━━━━━━━━━━ 22/22 9.9it/s 2.2s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.4it/s 0.1s
#                    all         25        104       0.79      0.386      0.337      0.141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      2.42G      1.493      1.756      1.929         19        640: 100% ━━━━━━━━━━━━ 22/22 9.2it/s 2.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.1it/s 0.1s
#                    all         25        104      0.797       0.38      0.353       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      2.42G       1.45       1.66      1.903         14        640: 100% ━━━━━━━━━━━━ 22/22 9.2it/s 2.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.1it/s 0.1s
#                    all         25        104      0.795      0.418      0.367      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      2.43G      1.426      1.645      1.888         26        640: 100% ━━━━━━━━━━━━ 22/22 9.2it/s 2.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 10.1it/s 0.1s
#                    all         25        104      0.811      0.418      0.387      0.188
#
# 20 epochs completed in 0.019 hours.
# Optimizer stripped from /home/mikey/Desktop/pipeline/runs/detect/runs/detect/carrot_v11/weights/last.pt, 5.5MB
# Optimizer stripped from /home/mikey/Desktop/pipeline/runs/detect/runs/detect/carrot_v11/weights/best.pt, 5.5MB
#
# Validating /home/mikey/Desktop/pipeline/runs/detect/runs/detect/carrot_v11/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# YOLO11n summary (fused): 101 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9s/it 2.9s
#                    all         25        104      0.826       0.38      0.383      0.166
#         Carrot_Damaged          3         12          1          0     0.0359    0.00875
#         Carrot_Healthy         22         92      0.651      0.761      0.731      0.323
# Speed: 0.2ms preprocess, 114.3ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /home/mikey/Desktop/pipeline/runs/detect/runs/detect/carrot_v11

# %% [markdown]
# ## 3. Train Lemon Model
# Using **YOLOv11n** (Nano) with enhanced HSV augmentation to help distinguish mold/rot colors.

# %%
model_lemon = YOLO('yolo11n.pt')
results_lemon = model_lemon.train(
    data=os.path.join(BASE_DIR, "dataset_lemon/data.yaml"),
    epochs=20,
    imgsz=640,
    project='runs/detect',
    name='lemon_v11',
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    degrees=90,
    fliplr=0.5,
    exist_ok=True
)
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_lemon/data.yaml, degrees=90, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=20, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=lemon_v11, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/mikey/Desktop/pipeline/runs/detect/runs/detect/lemon_v11, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431257  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# YOLO11n summary: 182 layers, 2,590,425 parameters, 2,590,409 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 117.1±46.9 MB/s, size: 29.3 KB)
# train: Scanning /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_lemon/train/labels.cache... 1428 images, 42 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1428/1428 332.7Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 75.1±38.4 MB/s, size: 37.0 KB)
# val: Scanning /home/mikey/Desktop/pdp_4th_grade/exam4/deeplearning/dataset_lemon/valid/labels.cache... 136 images, 8 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 136/136 3.0Mit/s 0.0s
# Plotting labels to /home/mikey/Desktop/pipeline/runs/detect/runs/detect/lemon_v11/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/mikey/Desktop/pipeline/runs/detect/runs/detect/lemon_v11
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20       2.4G     0.6282       2.46      1.051         14        640: 100% ━━━━━━━━━━━━ 90/90 4.3it/s 20.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.4it/s 3.5s0.2ss
#                    all        136        218      0.857      0.216      0.479      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.64G     0.6502      1.663      1.031         25        640: 100% ━━━━━━━━━━━━ 90/90 9.5it/s 9.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.2it/s 0.5s.1s
#                    all        136        218       0.43      0.637      0.503      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      2.64G     0.6757      1.548       1.04         15        640: 100% ━━━━━━━━━━━━ 90/90 9.4it/s 9.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.3it/s 0.5s.1s
#                    all        136        218      0.757      0.522      0.605      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      2.65G     0.6524      1.367      1.021         15        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 10.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.7it/s 0.5s.1s
#                    all        136        218      0.431      0.855      0.655      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.65G     0.6463        1.3      1.022         12        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 10.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 9.8it/s 0.5s0.2s
#                    all        136        218      0.474      0.718      0.688      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      2.65G     0.6307      1.213      1.017         13        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 10.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.8it/s 0.5s.1s
#                    all        136        218      0.389      0.768      0.591      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      2.65G     0.6052      1.157      1.011         18        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 10.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.5it/s 0.5s.1s
#                    all        136        218      0.502       0.76      0.634      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      2.66G     0.5574      1.103     0.9846          8        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 10.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.6it/s 0.5s.1s
#                    all        136        218      0.517      0.781      0.649      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      2.66G     0.5713      1.066     0.9925         18        640: 100% ━━━━━━━━━━━━ 90/90 8.9it/s 10.1s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.1it/s 0.5s.2s
#                    all        136        218      0.503      0.757      0.697      0.643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      2.66G     0.5255      0.986     0.9741         12        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 10.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.0it/s 0.5s.1s
#                    all        136        218      0.579      0.659      0.639      0.584
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      2.66G     0.4976      1.033     0.9771          4        640: 100% ━━━━━━━━━━━━ 90/90 8.7it/s 10.3s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.2it/s 0.4s.1s
#                    all        136        218      0.518      0.793      0.687      0.631
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      2.67G     0.4733      0.945     0.9453          4        640: 100% ━━━━━━━━━━━━ 90/90 9.1it/s 9.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.0it/s 0.5s.1s
#                    all        136        218      0.446      0.893      0.665      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      2.68G     0.4777     0.9167      0.953         11        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 10.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.7it/s 0.4s.4s
#                    all        136        218      0.467      0.788      0.645      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      2.69G     0.4446     0.8763     0.9276          4        640: 100% ━━━━━━━━━━━━ 90/90 9.1it/s 9.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.1it/s 0.4s.1s
#                    all        136        218       0.59        0.8      0.764      0.715
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      2.69G     0.4343     0.8265     0.9326          4        640: 100% ━━━━━━━━━━━━ 90/90 9.1it/s 9.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.3it/s 0.4s.1s
#                    all        136        218      0.575      0.807      0.744      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      2.69G     0.4137     0.7969      0.913          5        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 9.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.4it/s 0.4s.2s
#                    all        136        218      0.627      0.754      0.682      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      2.69G     0.4028     0.7584     0.9041          9        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 9.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.1it/s 0.5s.1s
#                    all        136        218       0.57      0.759      0.703      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      2.69G      0.385     0.7178     0.9001          7        640: 100% ━━━━━━━━━━━━ 90/90 9.1it/s 9.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 10.4it/s 0.5s.1s
#                    all        136        218      0.672        0.8      0.797      0.751
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      2.69G     0.3736     0.6983     0.8933          4        640: 100% ━━━━━━━━━━━━ 90/90 9.0it/s 10.0s.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.4it/s 0.4s.4s
#                    all        136        218      0.641      0.725      0.728       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      2.69G     0.3591     0.6521     0.8868          5        640: 100% ━━━━━━━━━━━━ 90/90 9.1it/s 9.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 11.6it/s 0.4s.1s
#                    all        136        218      0.735      0.764      0.803      0.762
#
# 20 epochs completed in 0.063 hours.
# Optimizer stripped from /home/mikey/Desktop/pipeline/runs/detect/runs/detect/lemon_v11/weights/last.pt, 5.5MB
# Optimizer stripped from /home/mikey/Desktop/pipeline/runs/detect/runs/detect/lemon_v11/weights/best.pt, 5.5MB
#
# Validating /home/mikey/Desktop/pipeline/runs/detect/runs/detect/lemon_v11/weights/best.pt...
# Ultralytics 8.4.8 🚀 Python-3.12.3 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7806MiB)
# YOLO11n summary (fused): 101 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.6it/s 0.8s0.2s
#                    all        136        218      0.735      0.764      0.803      0.762
#          Lemon_Damaged         37         53      0.653      0.868      0.791      0.758
#          Lemon_Healthy         72        115      0.725      0.904      0.824      0.772
#           Lemon_Unripe         25         50      0.827       0.52      0.795      0.756
# Speed: 0.2ms preprocess, 1.8ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /home/mikey/Desktop/pipeline/runs/detect/runs/detect/lemon_v11
